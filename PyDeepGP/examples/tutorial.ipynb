# %% [markdown]
# # PyDeepGP tutorial

# %%
import numpy as np
import GPy
from pylab import *
# %matplotlib inline
import os
from sys import path
np.random.seed(42)

# %%
# Add parent directory to path if deepgp is not there already
pwd = os.getcwd()
base_path = pwd[0:pwd.rfind(os.sep)]
path.insert(0,base_path)

# %%
import deepgp

# %%
# Utility to load sample data. It can be installed with pip. Otherwise just load some other data.
import pods

# %% [markdown]
# ## Unsupervised learning (oil data)

# %%
# Load data
data = pods.datasets.oil_100()
Y = data['X']
labels =  data['Y'].argmax(axis=1)

# Number of latent dimensions per layer
Q1, Q2 = 5, 4

# Type of kernel per layer
kern1 = GPy.kern.RBF(Q1,ARD=True) + GPy.kern.Bias(Q1)
kern2 = GPy.kern.RBF(Q2,ARD=True) + GPy.kern.Bias(Q2)

# Number of inducing points per layer (can be set to different if given as list).
num_inducing = 40

# Whether to use back-constraint for variational posterior
back_constraint = False

# Dimensions of the MLP back-constraint if set to true
encoder_dims=[[300],[150]]

# %%
m = deepgp.DeepGP([Y.shape[1],Q1,Q2],
                  Y,kernels=[kern1,kern2], 
                  num_inducing=num_inducing, 
                  back_constraint=back_constraint, 
                  encoder_dims = encoder_dims)

# %%
# Make sure initial noise variance gives a reasonable signal to noise ratio
for i in range(len(m.layers)):
    output_var = m.layers[i].Y.var() if i==0 else m.layers[i].Y.mean.var()
    m.layers[i].Gaussian_noise.variance = output_var*0.01

# %%
m.optimize(max_iters=5000, messages=True)
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0001   7.755559e+04   8.005322e+09
#     01s12  0037   1.108158e+02   7.873395e+02
#     03s13  0121  -5.507231e+01   1.949809e+02
#     11s21  0447  -1.728118e+02   2.852418e+01
#     35s51  1340  -2.465651e+02   1.361611e+02
#     49s69  1848  -2.566525e+02   1.575437e+01
#  02m26s44  5002  -2.615853e+02   1.870644e+00
# Runtime:  02m26s44
# Optimization status: Maximum number of f evaluations reached

# %%
# Plot ARD scales per layer
m.obslayer.kern.plot_ARD()
m.layer_1.kern.plot_ARD()
# Out:
#  /Users/neil/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1710: MatplotlibDeprecationWarning:The *left* kwarg to `bar` is deprecated use *x* instead. Support for *left* will be removed in Matplotlib 3.0
#  /Users/neil/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:1999: UserWarning:This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
# From the plots above, we see which ones are the dominant dimensions for each layer. 
# So we use these dimensions in the visualization of the latent space below.
plt.figure(figsize=(5,5))
deepgp.util.visualize_DGP(m, labels, layer=0, dims=[1,2]); plt.title('Layer 0')
plt.figure(figsize=(5,5))
deepgp.util.visualize_DGP(m, labels, layer=1, dims=[0,1]); plt.title('Layer 1')
# Out:
# Text(0.5,1,'Layer 1')

# %% [markdown]
# ## Supervised learning

# %%
# Load some mocap data.
data = pods.datasets.cmu_mocap_35_walk_jog()

Ntr = 100
Nts = 500

# All data represented in Y_all, which is the angles of the movement of the subject
Y_all = data['Y']
perm = np.random.permutation(Ntr+Nts)
index_training = np.sort(perm[0:Ntr])
index_test     = np.sort(perm[Ntr:Ntr+Nts])

Y_all_tr = Y_all[index_training,:]
Y_all_ts = Y_all[index_test,    :]


# Some of the features (body joints) to be used as inputs, and some as outputs
X_tr = Y_all_tr[:,0:55].copy()
Y_tr = Y_all_tr[:, 55:].copy()

X_ts = Y_all_ts[:,0:55].copy()
Y_ts = Y_all_ts[:, 55:].copy()

# TODO: You might need to normalize the input and/or output data.
# Out:
# Acquiring resource: cmu_mocap
#
# Details of data:
# CMU Motion Capture data base. Captured by a Vicon motion capture system consisting of 12 infrared MX-40 cameras, each of which is capable of recording at 120 Hz with images of 4 megapixel resolution. Motions are captured in a working volume of approximately 3m x 8m. The capture subject wears 41 markers and a stylish black garment.
#
# Please cite:
# Please include this in your acknowledgements: The data used in this project was obtained from mocap.cs.cmu.edu.\nThe database was created with funding from NSF EIA-0196217.
#
# Data will be stored in /Users/manifect/ods_data_cache/cmu_mocap.
#
# You must also agree to the following license:
# From http://mocap.cs.cmu.edu. This data is free for use in research projects. You may include this data in commercially-sold products, but you may not resell this data directly, even in converted form. If you publish results obtained using this data, we would appreciate it if you would send the citation to your published paper to jkh+mocap@cs.cmu.edu, and also would add this text to your acknowledgments section: The data used in this project was obtained from mocap.cs.cmu.edu. The database was created with funding from NSF EIA-0196217.
#
# Do you wish to proceed with the download? [yes/no]
# yes
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35.asf -> /Users/manifect/ods_data_cache/cmu_mocap/35.asf
# |    Downloading   0.007MB     |
# |>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_01.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_01.amc
# |    Downloading   0.274MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_02.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_02.amc
# |    Downloading   0.310MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_03.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_03.amc
# |    Downloading   0.327MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_04.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_04.amc
# |    Downloading   0.331MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_05.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_05.amc
# |    Downloading   0.326MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_06.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_06.amc
# |    Downloading   0.336MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_07.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_07.amc
# |    Downloading   0.275MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_08.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_08.amc
# |    Downloading   0.348MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_09.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_09.amc
# |    Downloading   0.294MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_10.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_10.amc
# |    Downloading   0.330MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_11.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_11.amc
# |    Downloading   0.295MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_12.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_12.amc
# |    Downloading   0.304MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_13.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_13.amc
# |    Downloading   0.347MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_14.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_14.amc
# |    Downloading   0.315MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_15.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_15.amc
# |    Downloading   0.311MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_16.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_16.amc
# |    Downloading   0.339MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_17.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_17.amc
# |    Downloading   0.127MB     |
# |>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_19.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_19.amc
# |    Downloading   0.122MB     |
# |>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_20.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_20.amc
# |    Downloading   0.124MB     |
# |>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_21.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_21.amc
# |    Downloading   0.123MB     |
# |>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_22.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_22.amc
# |    Downloading   0.127MB     |
# |>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_23.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_23.amc
# |    Downloading   0.123MB     |
# |>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_24.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_24.amc
# |    Downloading   0.114MB     |
# |>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_25.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_25.amc
# |    Downloading   0.126MB     |
# |>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_26.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_26.amc
# |    Downloading   0.105MB     |
# |>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_28.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_28.amc
# |    Downloading   0.319MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_30.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_30.amc
# |    Downloading   0.315MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_31.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_31.amc
# |    Downloading   0.321MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_32.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_32.amc
# |    Downloading   0.300MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_33.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_33.amc
# |    Downloading   0.322MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_34.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_34.amc
# |    Downloading   0.317MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_18.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_18.amc
# |    Downloading   0.133MB     |
# |>>>>>>>>>>>>>>>>>>|
# Downloading  http://mocap.cs.cmu.edu/subjects/35/35_29.amc -> /Users/manifect/ods_data_cache/cmu_mocap/35_29.amc
# |    Downloading   0.380MB     |
# |>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>|

# %%
# Number of latent dimensions (single hidden layer, since the top layer is observed)
Q = 5

# Define what kernels to use per layer
kern1 = GPy.kern.RBF(Q,ARD=True) + GPy.kern.Bias(Q)
kern2 = GPy.kern.RBF(Q,ARD=False) + GPy.kern.Bias(X_tr.shape[1])

# Number of inducing points to use
num_inducing = 40

# Whether to use back-constraint for variational posterior
back_constraint = False

# Dimensions of the MLP back-constraint if set to true
encoder_dims=[[300],[150]]

# %%
m = deepgp.DeepGP([Y_tr.shape[1],Q,X_tr.shape[1]],
                  Y_tr, X_tr=X_tr,kernels=[kern1, kern2], 
                  num_inducing=num_inducing, back_constraint=back_constraint)

# %%
[Y_tr.shape[1],Q,X_tr.shape[1]]
# Out:
# [7, 5, 55]

# %%
Y_tr.shape,X_tr.shape
# Out:
# ((100, 7), (100, 55))

# %%
# Make sure initial noise variance gives a reasonable signal to noise ratio.
# Fix to that value for a few iterations to avoid early local minima
for i in range(len(m.layers)):
    output_var = m.layers[i].Y.var() if i==0 else m.layers[i].Y.mean.var()
    m.layers[i].Gaussian_noise.variance = output_var*0.00
    m.layers[i].Gaussian_noise.variance.fix()

# %%
kern1
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sum.           </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance   </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale</td><td class=tg-right> (5,)</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  bias.variance  </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
kern2
# Out:
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  sum.           </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance   </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  bias.variance  </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
m.optimize(max_iters=800, messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=800), HTML(value=''))), Box(children=(HTML(value=''),))…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/model.py:111, in Model.optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     110 with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111     opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     113 self.optimizer_array = opt.x_opt
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/optimization/optimization.py:51, in Optimizer.run(self, x_init, **kwargs)
#      50 start = dt.datetime.now()
# ---> 51 self.opt(x_init, **kwargs)
#      52 end = dt.datetime.now()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/optimization/optimization.py:124, in opt_lbfgsb.opt(self, x_init, f_fp, f, fp)
#     122     opt_dict['factr'] = self.bfgs_factor
# --> 124 opt_result = optimize.fmin_l_bfgs_b(f_fp, x_init, maxfun=self.max_iters, maxiter=self.max_iters, **opt_dict)
#     125 self.x_opt = opt_result[0]
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py:197, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     186 opts = {'disp': disp,
#     187         'iprint': iprint,
#     188         'maxcor': m,
#    (...)
#     194         'callback': callback,
#     195         'maxls': maxls}
# --> 197 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                        **opts)
#     199 d = {'grad': res['jac'],
#     200      'task': res['message'],
#     201      'funcalls': res['nfev'],
#     202      'nit': res['nit'],
#     203      'warnflag': res['status']}
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     355 if task_str.startswith(b'FG'):
#     356     # The minimization routine wants f and g at the current x.
#     357     # Note that interruptions due to maxfun are postponed
#     358     # until the completion of the current minimization iteration.
#     359     # Overwrite f and g:
# --> 360     f, g = func_and_grad(x)
#     361 elif task_str.startswith(b'NEW_X'):
#     362     # new iteration
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun_and_grad(self, x)
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 self._update_grad()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     232 if not self.f_updated:
# --> 233     self._update_fun_impl()
#     234     self.f_updated = True
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      73 """ returns the the function value """
# ---> 74 self._compute_if_needed(x, *args)
#      75 return self._value
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/scipy/optimize/optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      67 self.x = np.asarray(x).copy()
# ---> 68 fg = self.fun(x, *args)
#      69 self.jac = fg[1]
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/model.py:273, in Model._objective_grads(self, x)
#     272 try:
# --> 273     self.optimizer_array = x
#     274     obj_f, self.obj_grads = self.objective_function(), self._transform_gradients(self.objective_function_gradients())
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/parameterized.py:339, in Parameterized.__setattr__(self, name, val)
#     338         param[:] = val; return
# --> 339 return object.__setattr__(self, name, val)
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/models/model.py:370, in DeepGP.optimizer_array(self, p)
#     369     self.mpi_comm.Bcast(p, root=self.mpi_root)
# --> 370 Model.optimizer_array.fset(self,p)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/parameter_core.py:124, in OptimizationHandlable.optimizer_array(self, p)
#     123 self._optimizer_copy_transformed = False
# --> 124 self.trigger_update()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/updateable.py:79, in Updateable.trigger_update(self, trigger_parent)
#      78     return
# ---> 79 self._trigger_params_changed(trigger_parent)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/parameter_core.py:133, in OptimizationHandlable._trigger_params_changed(self, trigger_parent)
#     127 """
#     128 First tell all children to update,
#     129 then update yourself.
#     130
#     131 If trigger_parent is True, we will tell the parent, otherwise not.
#     132 """
# --> 133 [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
#     134 self.notify_observers(None, None if trigger_parent else -np.inf)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/parameter_core.py:133, in <listcomp>(.0)
#     127 """
#     128 First tell all children to update,
#     129 then update yourself.
#     130
#     131 If trigger_parent is True, we will tell the parent, otherwise not.
#     132 """
# --> 133 [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
#     134 self.notify_observers(None, None if trigger_parent else -np.inf)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/parameter_core.py:134, in OptimizationHandlable._trigger_params_changed(self, trigger_parent)
#     133 [p._trigger_params_changed(trigger_parent=False) for p in self.parameters if not p.is_fixed]
# --> 134 self.notify_observers(None, None if trigger_parent else -np.inf)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/observable.py:96, in Observable.notify_observers(self, which, min_priority)
#      95     break
# ---> 96 callble(self, which=which)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/core/parameter_core.py:508, in Parameterizable._parameters_changed_notification(self, me, which)
#     507 self._optimizer_copy_transformed = False # tells the optimizer array to update on next request
# --> 508 self.parameters_changed()
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/layers/layers.py:64, in SparseGP_MPI.parameters_changed(self)
#      63 def parameters_changed(self):
# ---> 64     if self.auto_update: self.update_layer()
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/layers/layers.py:264, in Layer.update_layer(self)
#     263 def update_layer(self):
# --> 264     super(Layer,self).update_layer()
#     265     if self.uncertain_inputs:
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/layers/layers.py:67, in SparseGP_MPI.update_layer(self)
#      66 def update_layer(self):
# ---> 67     self._inference_vardtc()
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/layers/layers.py:99, in SparseGP_MPI._inference_vardtc(self)
#      98 else:
# ---> 99     self.kern.update_gradients_expectations(variational_posterior=self.X,
#     100                                             Z=self.Z,
#     101                                             dL_dpsi0=self.grad_dict['dL_dpsi0'],
#     102                                             dL_dpsi1=self.grad_dict['dL_dpsi1'],
#     103                                             dL_dpsi2=self.grad_dict['dL_dpsi2'])
#     104 kerngrad = self.kern.gradient.copy()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/kernel_slice_operations.py:283, in _slice_update_gradients_expectations.<locals>.wrap(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#     282 with _Slice_wrap(self, Z, variational_posterior) as s:
# --> 283     ret = f(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, s.X, s.X2)
#     284 return ret
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/add.py:224, in Add.update_gradients_expectations(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#     223         eff_dL_dpsi1 += tmp * p2.psi1(Z, variational_posterior)
# --> 224 p1.update_gradients_expectations(dL_dpsi0, eff_dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/kernel_slice_operations.py:283, in _slice_update_gradients_expectations.<locals>.wrap(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#     282 with _Slice_wrap(self, Z, variational_posterior) as s:
# --> 283     ret = f(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, s.X, s.X2)
#     284 return ret
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/rbf.py:196, in RBF.update_gradients_expectations(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#     195 def update_gradients_expectations(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior):
# --> 196     dL_dvar, dL_dlengscale = self.psicomp.psiDerivativecomputations(self, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)[:2]
#     197     self.variance.gradient = dL_dvar
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/caching.py:283, in Cache_this.__call__.<locals>.g(obj, *args, **kw)
#     282     cacher = cache[self.f] = Cacher(self.f, self.limit, self.ignore_args, self.force_kwargs, cacher_enabled=cache.caching_enabled)
# --> 283 return cacher(*args, **kw)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/caching.py:179, in Cacher.__call__(self, *args, **kw)
#     178 try:
# --> 179     new_output = self.operation(*args, **kw)
#     180 except:
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/psi_comp/__init__.py:38, in PSICOMP_RBF.psiDerivativecomputations(self, kern, dL_dpsi0, dL_dpsi1, dL_dpsi2, Z, variational_posterior)
#      37 if isinstance(variational_posterior, variational.NormalPosterior):
# ---> 38     return rbf_psi_comp.psiDerivativecomputations(dL_dpsi0, dL_dpsi1, dL_dpsi2, variance, lengthscale, Z, variational_posterior)
#      39 elif isinstance(variational_posterior, variational.SpikeAndSlabPosterior):
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/psi_comp/rbf_psi_comp.py:56, in psiDerivativecomputations(dL_dpsi0, dL_dpsi1, dL_dpsi2, variance, lengthscale, Z, variational_posterior)
#      55 dvar_psi1, dl_psi1, dZ_psi1, dmu_psi1, dS_psi1 = _psi1compDer(dL_dpsi1, variance, lengthscale, Z, variational_posterior.mean, variational_posterior.variance)
# ---> 56 dvar_psi2, dl_psi2, dZ_psi2, dmu_psi2, dS_psi2 = _psi2compDer(dL_dpsi2, variance, lengthscale, Z, variational_posterior.mean, variational_posterior.variance)
#      58 dL_dvar = np.sum(dL_dpsi0) + dvar_psi1 + dvar_psi2
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/GPy/kern/src/psi_comp/rbf_psi_comp.py:129, in _psi2compDer(dL_dpsi2, variance, lengthscale, Z, mu, S)
#     127 Lpsi2_M = Lpsi2.sum(2)
#     128 _dL_dZ = -Lpsi2_N.sum(0)[:,None]*Z/lengthscale2+Lpsi2_N.dot(Z)/lengthscale2+ \
# --> 129          2*Lpsi2_M.T.dot(mu*denom) - Lpsi2_M.T.dot(denom)*Z - (Lpsi2.reshape(N,M*M).T.dot(denom).reshape(M,M,Q)*Z[None,:,:]).sum(1)#np.einsum('nmo,oq,nq->mq',Lpsi2,Z,denom)
#     130 _dL_dl = 2*lengthscale* ((S/lengthscale2*denom+np.square(mu*denom))*Lpsi2sum[:,None]+(Lpsi2Z2-Lpsi2Z2p)/(2*np.square(lengthscale2))-
#     131                          (2*mu*denom2)*Lpsi2Zhat+denom2*Lpsi2Zhat2).sum(axis=0)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 m.optimize(max_iters=800, messages=True)
#
# File ~/Desktop/Li Cheng project/GP code/PyDeepGP-master/deepgp/models/model.py:375, in DeepGP.optimize(self, optimizer, start, **kwargs)
#     373 self._IN_OPTIMIZATION_ = True
#     374 if self.mpi_comm is None:
# --> 375     super(DeepGP, self).optimize(optimizer,start,**kwargs)
#     376 elif self.mpi_comm.rank==self.mpi_root:
#     377     super(DeepGP, self).optimize(optimizer,start,**kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/model.py:111, in Model.optimize(self, optimizer, start, messages, max_iters, ipython_notebook, clear_after_finish, **kwargs)
#     108     opt = optimizer(max_iters=max_iters, **kwargs)
#     110 with VerboseOptimization(self, opt, maxiters=max_iters, verbose=messages, ipython_notebook=ipython_notebook, clear_after_finish=clear_after_finish) as vo:
# --> 111     opt.run(start, f_fp=self._objective_grads, f=self._objective, fp=self._grads)
#     113 self.optimizer_array = opt.x_opt
#     115 self.optimization_runs.append(opt)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/optimization/verbose_optimization.py:215, in VerboseOptimization.__exit__(self, type, value, traceback)
#     213 self.stop = time.time()
#     214 self.model.remove_observer(self)
# --> 215 self.print_out(self.stop - self.start)
#     217 if not self.ipython_notebook:
#     218     print()
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/paramz/optimization/verbose_optimization.py:148, in VerboseOptimization.print_out(self, seconds)
#     138             self.timestring = '{m:0>2d}m{s:0>2d}s{ms:0>2d}'.format(
#     139                 m=int(m), s=int(s), ms=int(ms))
#     140     if self.ipython_notebook:  # pragma: no cover
#     141         names_vals = [['optimizer', "{:s}".format(self.opt_name)],
#     142                       ['runtime', "{:>s}".format(self.timestring)],
#     143                       ['evaluation', "{:>0{l}}".format(
#     144                           self.iteration, l=self.len_maxiters)],
#     145                       ['objective', "{: > 12.3E}".format(self.fnow)],
#     146                       ['||gradient||',
#     147                           "{: >+12.3E}".format(float(self.current_gradient))],
# --> 148                       ['status', "{:s}".format(self.status)],
#     149                       ]
#     150         #message = "Lik:{:5.3E} Grad:{:5.3E} Lik:{:5.3E} Len:{!s}".format(float(m.log_likelihood()), np.einsum('i,i->', grads, grads), float(m.likelihood.variance), " ".join(["{:3.2E}".format(l) for l in m.kern.lengthscale.values]))
#     151         html_begin = """<style type="text/css">
#     152 .tg-opt  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
#     153 .tg-opt td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
#    (...)
#     157 </style>
#     158 <table class="tg-opt">"""
#
# TypeError: unsupported format string passed to NoneType.__format__

# %%
plot(m.predict(X_tr)[0])
plot(Y_tr)
# Out:
# [<matplotlib.lines.Line2D at 0x2a34c9b80>,
#  <matplotlib.lines.Line2D at 0x2a34c9bb0>,
#  <matplotlib.lines.Line2D at 0x2a34c9cd0>,
#  <matplotlib.lines.Line2D at 0x2a34c4760>,
#  <matplotlib.lines.Line2D at 0x2a34c9df0>,
#  <matplotlib.lines.Line2D at 0x2a34cf040>,
#  <matplotlib.lines.Line2D at 0x2a34cf160>]

# %%
# Unfix noise variance now that we have initialized the model
for i in range(len(m.layers)):
    m.layers[i].Gaussian_noise.variance.unfix()

# %%
m.optimize(max_iters=1500, messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0, max=1500), HTML(value=''))), Box(children=(HTML(value=''),)…

# %%
plot(m.predict(X_tr)[0])
plot(Y_tr)
# Out:
# [<matplotlib.lines.Line2D at 0x299d39f40>,
#  <matplotlib.lines.Line2D at 0x299d39f70>,
#  <matplotlib.lines.Line2D at 0x299d440d0>,
#  <matplotlib.lines.Line2D at 0x299ed5b20>,
#  <matplotlib.lines.Line2D at 0x299d441f0>,
#  <matplotlib.lines.Line2D at 0x299d44400>,
#  <matplotlib.lines.Line2D at 0x299d44520>]

# %% [markdown]
# ### Compare with GP

# %%
m_GP = GPy.models.SparseGPRegression(X=X_tr, Y=Y_tr, kernel=GPy.kern.RBF(X_tr.shape[1])+GPy.kern.Bias(X_tr.shape[1]), num_inducing=num_inducing)

# %%
m_GP.Gaussian_noise.variance = m_GP.Y.var()*0.01
m_GP.Gaussian_noise.variance.fix()
m_GP.optimize(max_iters=100, messages=True)
m_GP.Gaussian_noise.variance.unfix()
m_GP.optimize(max_iters=400, messages=True)
# Out:
# HBox(children=(VBox(children=(IntProgress(value=0), HTML(value=''))), Box(children=(HTML(value=''),))))
# HBox(children=(VBox(children=(IntProgress(value=0, max=400), HTML(value=''))), Box(children=(HTML(value=''),))…

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions.flatten() - targets.flatten()) ** 2).mean())

# %%
Y_pred = m.predict(X_ts)[0]
Y_pred_s = m.predict_withSamples(X_ts, nSamples=500)[0]
Y_pred_GP = m_GP.predict(X_ts)[0]

print('# RMSE DGP               : ' + str(rmse(Y_pred, Y_ts)))
print('# RMSE DGP (with samples): ' + str(rmse(Y_pred_s, Y_ts)))
print('# RMSE GP                : ' + str(rmse(Y_pred_GP, Y_ts)))
# Out:
# # RMSE DGP               : 3.0298391816442094
# # RMSE DGP (with samples): 3.0273346632928657
# # RMSE GP                : 3.033962910636556

# %%
# Number of latent dimensions (single hidden layer, since the top layer is observed)
Q = 5

# Define what kernels to use per layer
kern1 = GPy.kern.RBF(Q,ARD=True) + GPy.kern.Bias(Q)
kern2 = GPy.kern.RBF(Q,ARD=False) + GPy.kern.Bias(X_tr.shape[1])

# Number of inducing points to use
num_inducing = 40

# Whether to use back-constraint for variational posterior
back_constraint = False

# Dimensions of the MLP back-constraint if set to true
encoder_dims=[[300],[150]]

m = deepgp.DeepGP([Y_tr.shape[1],Q,X_tr.shape[1]],
                  Y_tr, X_tr=X_tr,kernels=[kern1, kern2], 
                  num_inducing=num_inducing, back_constraint=back_constraint)

# Make sure initial noise variance gives a reasonable signal to noise ratio.
# Fix to that value for a few iterations to avoid early local minima
for i in range(len(m.layers)):
    output_var = m.layers[i].Y.var() if i==0 else m.layers[i].Y.mean.var()
    m.layers[i].Gaussian_noise.variance = output_var*0.01
    m.layers[i].Gaussian_noise.variance.fix()
